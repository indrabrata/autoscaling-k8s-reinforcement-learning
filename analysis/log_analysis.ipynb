# %% [markdown]
# # Episode Log Comparison
#
# Extract and compare episode rewards from multiple log files.

# %%
import re
import matplotlib.pyplot as plt

# Specify the log files to compare
log_files = [
    r'logs\19-02-2026\qfuzzy.log',
    r'logs\19-02-2026\q.log'
]

# Labels for each log (will be shown in legend)
labels = [
    'Q-Learning Fuzzy',
    'Q-Learning'
]

# Pattern to match episode completion logs and extract episode number and reward
pattern = r'Episode (\d+) completed.*Total reward: ([\d\.\-e]+)'

print("Log files to compare:")
for i, log_file in enumerate(log_files, 1):
    print(f"  {i}. {log_file} ({labels[i-1]})")
print()
# Out:
# Log files to compare:
#   1. logs\19-02-2026\qfuzzy.log (Q-Learning Fuzzy)
#   2. logs\19-02-2026\q.log (Q-Learning)

# %%
# Extract episode data from all log files
all_data = []

for idx, log_file in enumerate(log_files):
    episodes = []
    rewards = []
    
    print("="*100)
    print(f"PROCESSING: {labels[idx]} ({log_file})")
    print("="*100)
    print()
    
    try:
        with open(log_file, 'r', encoding='utf-8') as f:
            for line in f:
                match = re.search(pattern, line)
                if match:
                    episode_num = int(match.group(1))
                    reward = float(match.group(2))
                    
                    episodes.append(episode_num)
                    rewards.append(reward)
                    
                    print(line.strip())
        
        print()
        print(f"Total episodes found: {len(episodes)}")
        
        if episodes:
            print(f"Mean reward: {sum(rewards)/len(rewards):.6f}")
            print(f"Min reward: {min(rewards):.6f}")
            print(f"Max reward: {max(rewards):.6f}")
        
        print()
        
        all_data.append({
            'label': labels[idx],
            'episodes': episodes,
            'rewards': rewards
        })
        
    except FileNotFoundError:
        print(f"Error: File '{log_file}' not found.\n")
        all_data.append({
            'label': labels[idx],
            'episodes': [],
            'rewards': []
        })
    except Exception as e:
        print(f"Error reading file: {e}\n")
        all_data.append({
            'label': labels[idx],
            'episodes': [],
            'rewards': []
        })

print("="*100)
# Out:
# ====================================================================================================
# PROCESSING: Q-Learning Fuzzy (logs\19-02-2026\qfuzzy.log)
# ====================================================================================================
#
# 2026-02-19 13:16:24,430 [INFO] root: Episode 1 completed. Total reward: -27.26873141139277
# 2026-02-19 13:49:34,215 [INFO] root: Episode 2 completed. Total reward: 0.47545911288936904
# 2026-02-19 14:23:04,051 [INFO] root: Episode 3 completed. Total reward: -10.442746791680454
# 2026-02-19 14:56:44,490 [INFO] root: Episode 4 completed. Total reward: -15.205854310754242
# 2026-02-19 15:30:09,411 [INFO] root: Episode 5 completed. Total reward: -8.91306236944687
# 2026-02-19 16:03:29,129 [INFO] root: Episode 6 completed. Total reward: -2.680914707469019
# 2026-02-19 16:36:49,463 [INFO] root: Episode 7 completed. Total reward: -19.395539962984678
# 2026-02-19 17:10:09,347 [INFO] root: Episode 8 completed. Total reward: -5.827045815240668
# 2026-02-19 17:43:34,425 [INFO] root: Episode 9 completed. Total reward: -6.059542935206798
# 2026-02-19 18:22:09,564 [INFO] root: Episode 10 completed. Total reward: 1.2565003865877178
# 2026-02-19 18:55:19,850 [INFO] root: Episode 11 completed. Total reward: -10.086172836724987
# 2026-02-19 19:28:34,015 [INFO] root: Episode 12 completed. Total reward: -11.822936566601598
# 2026-02-19 20:03:20,664 [INFO] root: Episode 13 completed. Total reward: -7.870539268029327
# 2026-02-19 20:37:19,586 [INFO] root: Episode 14 completed. Total reward: -27.451116128999097
# 2026-02-19 21:10:44,678 [INFO] root: Episode 15 completed. Total reward: -18.282232862439034
# 2026-02-19 21:44:04,311 [INFO] root: Episode 16 completed. Total reward: -3.1498229260375803
# 2026-02-19 22:17:34,474 [INFO] root: Episode 17 completed. Total reward: -6.583866476266244
# 2026-02-19 22:50:44,615 [INFO] root: Episode 18 completed. Total reward: 0.27284051458300507
# 2026-02-19 23:38:24,493 [INFO] root: Episode 19 completed. Total reward: -24.672584490524883
# 2026-02-20 00:23:04,419 [INFO] root: Episode 20 completed. Total reward: 8.203045136818098
# 2026-02-20 00:56:59,462 [INFO] root: Episode 21 completed. Total reward: -7.565038353010447
# 2026-02-20 01:35:28,981 [INFO] root: Episode 22 completed. Total reward: 4.144623588982071
# 2026-02-20 02:33:59,754 [INFO] root: Episode 23 completed. Total reward: -36.980031847701795
# 2026-02-20 03:35:20,150 [INFO] root: Episode 24 completed. Total reward: -104.32021873152898
# 2026-02-20 04:34:45,918 [INFO] root: Episode 25 completed. Total reward: -105.12000141164185
# 2026-02-20 05:34:10,338 [INFO] root: Episode 26 completed. Total reward: -95.39698325008625
# 2026-02-20 06:33:08,969 [INFO] root: Episode 27 completed. Total reward: -92.3763792932202
# 2026-02-20 07:06:09,718 [INFO] root: Episode 28 completed. Total reward: 1.9880903986271985
# 2026-02-20 07:39:18,998 [INFO] root: Episode 29 completed. Total reward: 1.8999628738365117
# 2026-02-20 08:14:09,420 [INFO] root: Episode 30 completed. Total reward: 4.697716520122608
# 2026-02-20 08:47:04,278 [INFO] root: Episode 31 completed. Total reward: -0.30795113397435137
# 2026-02-20 09:25:19,615 [INFO] root: Episode 32 completed. Total reward: 5.242110524497071
# 2026-02-20 09:58:44,656 [INFO] root: Episode 33 completed. Total reward: 0.6723110691463369
# 2026-02-20 10:37:09,229 [INFO] root: Episode 34 completed. Total reward: 0.7155180591938631
# 2026-02-20 11:10:19,125 [INFO] root: Episode 35 completed. Total reward: -2.792384061445648
# 2026-02-20 11:43:29,215 [INFO] root: Episode 36 completed. Total reward: 4.967526610713924
# 2026-02-20 12:22:08,892 [INFO] root: Episode 37 completed. Total reward: 6.852279668363424
# 2026-02-20 12:55:24,227 [INFO] root: Episode 38 completed. Total reward: 3.339158976006356
# 2026-02-20 13:28:34,355 [INFO] root: Episode 39 completed. Total reward: 2.2470901362755935
# 2026-02-20 14:02:54,306 [INFO] root: Episode 40 completed. Total reward: -2.3028563344332333
# 2026-02-20 14:36:39,452 [INFO] root: Episode 41 completed. Total reward: -4.398137525845329
# 2026-02-20 15:14:08,852 [INFO] root: Episode 42 completed. Total reward: 6.199907914583375
# 2026-02-20 15:46:54,154 [INFO] root: Episode 43 completed. Total reward: 7.324247592436411
# 2026-02-20 16:20:29,111 [INFO] root: Episode 44 completed. Total reward: 7.329644234845053
# 2026-02-20 16:53:24,231 [INFO] root: Episode 45 completed. Total reward: 1.1309202504743288
# 2026-02-20 17:25:59,072 [INFO] root: Episode 46 completed. Total reward: 6.5124189773353
# 2026-02-20 17:58:49,365 [INFO] root: Episode 47 completed. Total reward: 6.543217544019885
# 2026-02-20 18:37:53,987 [INFO] root: Episode 48 completed. Total reward: 4.7256089277470155
# 2026-02-20 19:12:04,487 [INFO] root: Episode 49 completed. Total reward: -0.6544770572445675
# 2026-02-20 19:44:49,551 [INFO] root: Episode 50 completed. Total reward: 3.873831148290227
# 2026-02-20 20:19:09,569 [INFO] root: Episode 51 completed. Total reward: 4.030434466636395
# 2026-02-20 20:51:44,117 [INFO] root: Episode 52 completed. Total reward: 4.9574098613446935
# 2026-02-20 21:27:49,573 [INFO] root: Episode 53 completed. Total reward: 4.108269930873334
# 2026-02-20 22:00:54,357 [INFO] root: Episode 54 completed. Total reward: 4.786832656872892
# 2026-02-20 22:33:54,153 [INFO] root: Episode 55 completed. Total reward: 5.367881395781244
# 2026-02-20 23:06:54,481 [INFO] root: Episode 56 completed. Total reward: 4.312253071883883
# 2026-02-20 23:40:09,770 [INFO] root: Episode 57 completed. Total reward: 2.9636993418750435
# 2026-02-21 00:14:30,288 [INFO] root: Episode 58 completed. Total reward: 27.579946341201335
# 2026-02-21 00:46:19,239 [INFO] root: Episode 59 completed. Total reward: 27.333333333333336
# 2026-02-21 01:17:54,081 [INFO] root: Episode 60 completed. Total reward: 28.444444444444443
#
# Total episodes found: 60
# Mean reward: -7.557144
# Min reward: -105.120001
# Max reward: 28.444444
#
# ====================================================================================================
# PROCESSING: Q-Learning (logs\19-02-2026\q.log)
# ====================================================================================================
#
# 2026-02-19 13:15:29,038 [INFO] root: Episode 1 completed. Total reward: -7.74019365648105
# 2026-02-19 13:48:49,381 [INFO] root: Episode 2 completed. Total reward: -16.21052684700931
# 2026-02-19 14:22:39,365 [INFO] root: Episode 3 completed. Total reward: -24.659268682514604
# 2026-02-19 14:55:44,024 [INFO] root: Episode 4 completed. Total reward: -35.40311475186477
# 2026-02-19 15:29:14,671 [INFO] root: Episode 5 completed. Total reward: -40.519057527692816
# 2026-02-19 16:02:59,259 [INFO] root: Episode 6 completed. Total reward: -32.230385728994264
# 2026-02-19 16:35:54,069 [INFO] root: Episode 7 completed. Total reward: -33.07109093433175
# 2026-02-19 17:09:09,042 [INFO] root: Episode 8 completed. Total reward: -35.84409072609158
# 2026-02-19 17:42:23,902 [INFO] root: Episode 9 completed. Total reward: -23.923429651804184
# 2026-02-19 18:20:09,554 [INFO] root: Episode 10 completed. Total reward: -20.68529173102417
# 2026-02-19 18:53:09,828 [INFO] root: Episode 11 completed. Total reward: -40.24426857209782
# 2026-02-19 19:25:54,622 [INFO] root: Episode 12 completed. Total reward: -53.48535362794467
# 2026-02-19 19:58:39,422 [INFO] root: Episode 13 completed. Total reward: -54.1262484843059
# 2026-02-19 20:33:09,064 [INFO] root: Episode 14 completed. Total reward: -54.15535692215765
# 2026-02-19 21:05:39,861 [INFO] root: Episode 15 completed. Total reward: -55.328270204268534
# 2026-02-19 21:38:03,978 [INFO] root: Episode 16 completed. Total reward: -58.544344516529634
# 2026-02-19 22:11:04,115 [INFO] root: Episode 17 completed. Total reward: -44.55235720907354
# 2026-02-19 22:43:54,029 [INFO] root: Episode 18 completed. Total reward: -49.56537793827872
# 2026-02-19 23:17:49,004 [INFO] root: Episode 19 completed. Total reward: -25.300668551461378
# 2026-02-19 23:53:05,119 [INFO] root: Episode 20 completed. Total reward: -53.46849918905999
# 2026-02-20 00:36:28,963 [INFO] root: Episode 21 completed. Total reward: -82.82283787533163
# 2026-02-20 01:14:18,850 [INFO] root: Episode 22 completed. Total reward: -55.35981109076476
# 2026-02-20 01:50:49,101 [INFO] root: Episode 23 completed. Total reward: -45.35286920879338
# 2026-02-20 02:26:44,325 [INFO] root: Episode 24 completed. Total reward: -83.84356890265533
# 2026-02-20 03:04:24,641 [INFO] root: Episode 25 completed. Total reward: -98.49953774679302
# 2026-02-20 03:46:54,931 [INFO] root: Episode 26 completed. Total reward: -79.82562019332498
# 2026-02-20 04:25:29,559 [INFO] root: Episode 27 completed. Total reward: -93.00361916501748
# 2026-02-20 05:01:45,367 [INFO] root: Episode 28 completed. Total reward: -103.12496391459402
# 2026-02-20 05:44:24,460 [INFO] root: Episode 29 completed. Total reward: -76.03713175009736
# 2026-02-20 06:25:24,754 [INFO] root: Episode 30 completed. Total reward: -93.3403690919482
# 2026-02-20 06:58:34,530 [INFO] root: Episode 31 completed. Total reward: -73.16005629766121
# 2026-02-20 07:30:19,579 [INFO] root: Episode 32 completed. Total reward: -58.6251391564126
# 2026-02-20 08:02:34,982 [INFO] root: Episode 33 completed. Total reward: -58.04845779399053
# 2026-02-20 08:34:04,210 [INFO] root: Episode 34 completed. Total reward: -58.72959483981353
# 2026-02-20 09:06:34,035 [INFO] root: Episode 35 completed. Total reward: -49.35112895293627
# 2026-02-20 09:39:33,976 [INFO] root: Episode 36 completed. Total reward: -52.23497469944065
# 2026-02-20 10:11:06,970 [INFO] root: Episode 37 completed. Total reward: -67.77798651769635
# 2026-02-20 10:42:54,764 [INFO] root: Episode 38 completed. Total reward: -48.578726106699094
# 2026-02-20 11:14:24,751 [INFO] root: Episode 39 completed. Total reward: -67.40716163629884
# 2026-02-20 11:46:04,749 [INFO] root: Episode 40 completed. Total reward: -61.50184436530953
# 2026-02-20 12:17:29,356 [INFO] root: Episode 41 completed. Total reward: -60.674555420508675
# 2026-02-20 12:49:24,556 [INFO] root: Episode 42 completed. Total reward: -65.43800672091425
# 2026-02-20 13:20:54,625 [INFO] root: Episode 43 completed. Total reward: -67.84998720186637
# 2026-02-20 13:52:18,975 [INFO] root: Episode 44 completed. Total reward: -60.08888175287993
# 2026-02-20 14:29:04,613 [INFO] root: Episode 45 completed. Total reward: -50.89017955940936
# 2026-02-20 15:05:40,505 [INFO] root: Episode 46 completed. Total reward: -93.53354083828391
# 2026-02-20 15:37:30,751 [INFO] root: Episode 47 completed. Total reward: -71.48558173934855
# 2026-02-20 16:08:40,505 [INFO] root: Episode 48 completed. Total reward: -66.90205134948583
# 2026-02-20 16:40:01,756 [INFO] root: Episode 49 completed. Total reward: -68.71206442007933
# 2026-02-20 17:11:40,880 [INFO] root: Episode 50 completed. Total reward: -62.99787869241202
# 2026-02-20 17:43:13,913 [INFO] root: Episode 51 completed. Total reward: -56.8129031826929
# 2026-02-20 18:26:09,220 [INFO] root: Episode 52 completed. Total reward: -59.255638679521326
# 2026-02-20 18:58:09,131 [INFO] root: Episode 53 completed. Total reward: -97.28726202652652
# 2026-02-20 19:29:40,720 [INFO] root: Episode 54 completed. Total reward: -93.91985101962607
# 2026-02-20 20:02:44,093 [INFO] root: Episode 55 completed. Total reward: -44.4235814891447
# 2026-02-20 20:34:34,474 [INFO] root: Episode 56 completed. Total reward: -60.02609056763388
# 2026-02-20 21:05:55,022 [INFO] root: Episode 57 completed. Total reward: -68.04627240759385
# 2026-02-20 21:37:09,590 [INFO] root: Episode 58 completed. Total reward: -71.85678630088476
# 2026-02-20 22:08:55,088 [INFO] root: Episode 59 completed. Total reward: -49.61679346148136
# 2026-02-20 22:40:10,966 [INFO] root: Episode 60 completed. Total reward: -68.7699871889074
#
# Total episodes found: 60
# Mean reward: -58.404508
# Min reward: -103.124964
# Max reward: -7.740194
#
# ====================================================================================================

# %%
# Visualize reward comparison
if any(data['episodes'] for data in all_data):
    fig, ax = plt.subplots(figsize=(16, 7))
    
    # Define colors for each line
    colors = ['#2E86AB', '#06A77D', '#F18F01', '#D62828', '#A23B72']
    
    # Plot each log file's data
    for idx, data in enumerate(all_data):
        if data['episodes']:
            ax.plot(data['episodes'], data['rewards'], 
                   linewidth=2.5, 
                   color=colors[idx % len(colors)],
                   label=data['label'],
                   alpha=0.8)
    
    ax.set_xlabel('Episode', fontsize=12, fontweight='bold')
    ax.set_ylabel('Reward', fontsize=12, fontweight='bold')
    ax.set_title('Reward per Episode - Comparison', fontsize=14, fontweight='bold', pad=20)
    ax.grid(True, alpha=0.3, linestyle='--')
    ax.legend(loc='best', fontsize=11, framealpha=0.9)
    
    # Add zero line for reference
    ax.axhline(y=0, color='red', linestyle='--', alpha=0.3, linewidth=1)
    
    plt.tight_layout()
    plt.show()
    
    # Print comparison statistics
    print("\n" + "="*100)
    print("COMPARISON SUMMARY")
    print("="*100)
    
    for data in all_data:
        if data['episodes']:
            print(f"\n{data['label']}:")
            print(f"  Episodes: {len(data['episodes'])}")
            print(f"  Mean Reward: {sum(data['rewards'])/len(data['rewards']):.6f}")
            print(f"  Min Reward: {min(data['rewards']):.6f} (Episode {data['episodes'][data['rewards'].index(min(data['rewards']))]})")
            print(f"  Max Reward: {max(data['rewards']):.6f} (Episode {data['episodes'][data['rewards'].index(max(data['rewards']))]})")
            print(f"  Total Cumulative Reward: {sum(data['rewards']):.6f}")
    
    print("\n" + "="*100)
    
else:
    print("No episode data to visualize.")
# Out:
# ====================================================================================================
# COMPARISON SUMMARY
# ====================================================================================================
#
# Q-Learning Fuzzy:
#   Episodes: 60
#   Mean Reward: -7.557144
#   Min Reward: -105.120001 (Episode 25)
#   Max Reward: 28.444444 (Episode 60)
#   Total Cumulative Reward: -453.428634
#
# Q-Learning:
#   Episodes: 60
#   Mean Reward: -58.404508
#   Min Reward: -103.124964 (Episode 28)
#   Max Reward: -7.740194 (Episode 1)
#   Total Cumulative Reward: -3504.270489
#
# ====================================================================================================

# %%
# Optional: Plot cumulative reward comparison
if any(data['episodes'] for data in all_data):
    fig, ax = plt.subplots(figsize=(16, 7))
    
    colors = ['#2E86AB', '#06A77D', '#F18F01', '#D62828', '#A23B72']
    
    for idx, data in enumerate(all_data):
        if data['episodes']:
            
            # Calculate cumulative reward
            cumulative_rewards = []
            total = 0
            for reward in data['rewards']:
                total += reward
                cumulative_rewards.append(total)
            
            ax.plot(data['episodes'], cumulative_rewards,
                   linewidth=3,
                   color=colors[idx % len(colors)],
                   label=data['label'],
                   alpha=0.8,
                   marker='o',
                   markersize=6,
                   markevery=max(1, len(data['episodes'])//10))
    
    ax.set_xlabel('Episode', fontsize=12, fontweight='bold')
    ax.set_ylabel('Cumulative Reward', fontsize=12, fontweight='bold')
    ax.set_title('Cumulative Reward per Episode - Comparison', fontsize=14, fontweight='bold', pad=20)
    ax.grid(True, alpha=0.3, linestyle='--')
    ax.legend(loc='best', fontsize=11, framealpha=0.9)
    
    plt.tight_layout()
    plt.show()
